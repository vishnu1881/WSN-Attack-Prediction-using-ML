# %% [markdown]
# # Module 2

# %% [markdown]
# Exploratory Data Analysis of Visualization

# %%
#import library packages
import pandas as p
import matplotlib.pyplot as plt
import seaborn as s
import numpy as n

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df = p.read_csv("WSN_Dataset.csv")

# %%
df
# Out:
#            id  Time  Is_CH  who_CH  Dist_To_CH  ADV_S  ADV_R  JOIN_S  JOIN_R  \
# 0           0    50      1  101000     0.00000      1      0       0      25
# 1           1    50      0  101044    75.32345      0      4       1       0
# 2           2    50      0  101010    46.95453      0      4       1       0
# 3           3    50      0  101044    64.85231      0      4       1       0
# 4           4    50      0  101010     4.83341      0      4       1       0
# ...       ...   ...    ...     ...         ...    ...    ...     ...     ...
# 50381  373986   703      1  114021     0.00000      1      6       0      26
# 50382  374130   753      1  115065     0.00000      1      4       0      55
# 50383  374270   853      1  117005     0.00000      1     10       0      14
# 50384  374342   853      1  117078     0.00000      1     10       0      11
# 50385  374523   953      1  119061     0.00000      1      6       0      31
#
# ...

# %%
df.columns
# Out:
# Index(['id', 'Time', 'Is_CH', 'who_CH', 'Dist_To_CH', 'ADV_S', 'ADV_R',
#        'JOIN_S', 'JOIN_R', 'SCH_S', 'SCH_R', 'Rank', 'DATA_S', 'DATA_R',
#        'Data_Sent_To_BS', 'dist_CH_To_BS', 'send_code', 'Expaned_Energy',
#        'Attack_type'],
#       dtype='object')

# %%
df['Time'].hist(figsize=(10,4), color='purple')
plt.xlabel('Time')
plt.ylabel('Count')
plt.title('Time Distribution')
# Out:
# Text(0.5, 1.0, 'Time Distribution')

# %%
plt.boxplot(df['send_code'])
plt.show()

# %%
import seaborn as s
s.boxplot(df['Time'], color='c')
# Out:
# <AxesSubplot:xlabel='Time'>

# %%
#Propagation by variable
def PropByVar(df, variable):
    dataframe_pie = df[variable].value_counts()
    ax = dataframe_pie.plot.pie(figsize=(8,8), autopct='%1.2f%%', fontsize = 12)
    ax.set_title(variable + ' \n', fontsize = 15)
    return n.round(dataframe_pie/df.shape[0]*100,2)

PropByVar(df, 'ADV_R')
# Out:
# 26    14.35
# 0     10.87
# 28     8.32
# 27     7.88
# 25     7.78
# 4      5.98
# 6      5.88
# 9      5.80
# 5      5.22
# 7      4.42
# 3      4.31
# 24     3.21
# 8      2.98
# 2      2.01
# 23     1.48
# 10     1.24
# 11     1.12
# 12     1.01
# 1      0.83
# 22     0.78
# 13     0.75
# 19     0.69
# 20     0.59
# 21     0.57
# 16     0.53
# 15     0.43
# 14     0.35
# 17     0.31
# 18     0.31
# Name: ADV_R, dtype: float64

# %%
#Propagation by variable
def PropByVar(df, variable):
    dataframe_pie = df[variable].value_counts()
    ax = dataframe_pie.plot.pie(figsize=(8,8), autopct='%1.2f%%', fontsize = 12)
    ax.set_title(variable + ' \n', fontsize = 15)
    return n.round(dataframe_pie/df.shape[0]*100,2)

PropByVar(df, 'Attack_type')
# Out:
# Normal       31.34
# Grayhole     28.97
# Blackhole    19.94
# TDMA         13.17
# Flooding      6.57
# Name: Attack_type, dtype: float64

# %%
# Heatmap plot diagram
fig, ax = plt.subplots(figsize=(15,6))
s.heatmap(df.corr(), ax=ax, annot=True)
# Out:
# <AxesSubplot:>

# %%
fig, ax = plt.subplots(figsize=(8,4))
ax.scatter(df['Attack_type'],df['send_code'])
ax.set_xlabel('Attack_Type')
ax.set_ylabel('Send Code')
plt.title('Scatter Plot')
plt.show()

# %%
plt.plot(df["Attack_type"], df["Is_CH"], color='blue')
plt.xlabel('Attack_Type')
plt.ylabel('Is_CH')
plt.title('Distribution of Is_CH and Attack_Type')
plt.show()

# %%
plt.figure(figsize= (10,4))
df["Is_CH"].plot(kind='density')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
plt.figure(figsize= (10,4))
df["who_CH"].plot(kind='density')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
plt.figure(figsize=(10,6))
plt.scatter(df["Attack_type"],df["who_CH"],color="red")

# %%
plt.hist(df['Attack_type'],color="blue")
plt.xlabel("Attack Types")
plt.show()
